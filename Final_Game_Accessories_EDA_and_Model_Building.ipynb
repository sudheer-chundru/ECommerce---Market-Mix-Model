# %%
#supressing the warnings
import warnings
warnings.filterwarnings('ignore')

#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
# Setting display options for the rows and columns
pd.set_option('display.max_row', 200)
pd.set_option('display.max_columns', 100)
pd.set_option('display.float_format', '{:0.3f}'.format)

# %%
# Mounting the google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # 1. Data Reading and Understanding

# %%
# importing/reading the csv file
path = '/content/gdrive/MyDrive/E Commerce Capstone Project/Project FIles/gaming_accessories.csv'
game_df = pd.read_csv(path)
game_df.head()
# Out:
#    Unnamed: 0  week  special_sale  Payday     Year  Month    Day  \
# 0           0     1         0.000   0.200 2015.000  7.000  3.000
# 1           1     2         0.000   0.000 2015.000  7.000  9.000
# 2           2     3         0.286   0.143 2015.000  7.000 16.000
# 3           3     4         0.000   0.000 2015.000  7.000 23.000
# 4           4     5         0.000   0.143 2015.000  7.286 21.143
#
#    Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  Heat Deg Days (°C)  \
# 0         25.500         13.200          19.360               0.100
# 1         24.025         14.385          19.263               1.059
# 2         27.383         16.314          21.906               0.816
# 3         28.240         14.342          20.540               1.632
# 4         29.811         16.242          23.092               0.816
#
#    Cool Deg Days (°C)  Total Rain (mm)  Total Snow (cm)  Total Precip (mm)  \
# 0               1.460            0.000            0.000              0.000
# 1               2.322            4.155            0.029              4.184
# 2               4.722            1.569            0.029              1.598
# 3               4.172            1.141            0.029              1.170
# 4               5.908            4.341            0.029              4.370
#
#    Snow on Grnd (cm)    NPS  Stock_Index  Total Investment    TV  Digital  \
# 0              0.000 54.600     1177.000             4.265 0.054    0.633
# 1              0.041 54.600     1177.000             4.265 0.054    0.633
# 2              0.041 54.600     1177.000             4.265 0.054    0.633
# 3              0.041 54.600     1177.000             4.265 0.054    0.633
# 4              0.041 56.139     1185.286             1.013 0.001    0.256
#
#    Sponsorship  Content  Online  Affiliates   SEM  Radio  Other  TV_adstock  \
# 0        1.854    0.000   0.332       0.137 1.256  0.000  0.000       0.054
# 1        1.854    0.000   0.332       0.137 1.256  0.000  0.000       0.081
# 2        1.854    0.000   0.332       0.137 1.256  0.000  0.000       0.081
# 3        1.854    0.000   0.332       0.137 1.256  0.000  0.000       0.081
# 4        0.213    0.000   0.026       0.015 0.503  0.000  0.000       0.028
#
#    Digital_adstock  Sponsorship_adstock  Content_adstock  Online_adstock  \
# 0            0.633                1.854            0.000           0.332
# 1            0.950                2.780            0.000           0.498
# 2            0.950                2.780            0.000           0.498
# 3            0.950                2.780            0.000           0.498
# 4            0.572                1.139            0.000           0.192
#
#    Affiliates_adstock  SEM_adstock  Radio_adstock  Other_adstock  order_id  \
# 0               0.137        1.256          0.000          0.000        19
# 1               0.205        1.884          0.000          0.000      2221
# 2               0.205        1.884          0.000          0.000      2051
# 3               0.205        1.884          0.000          0.000      1745
# 4               0.083        1.131          0.000          0.000      1108
#
#    order_item_id   sla  product_procurement_sla  product_mrp  units     gmv  \
# 0             19 4.158                    2.526      666.421      1 499.368
# 1           2343 5.293                    3.120      894.309      1 467.896
# 2           2076 5.221                    2.589      668.555      1 380.714
# 3           1776 5.252                    2.401      800.160      1 489.387
# 4           1124 5.682                    2.332      783.811      1 483.509
#
#    listed_price  discount_percent  total_price   COD  luxury_product
# 0       499.368            22.860      666.421     0               0
# 1       467.896            42.474      894.309  1730               0
# 2       380.714            43.572      668.555  1622               0
# 3       489.387            35.986      800.160  1406               0
# 4       483.509            36.695      783.811   921               0

# %%
# Dropping  unimportant columns

game_df.drop(columns=['Unnamed: 0', 'Year', 'Month', 'Day'], axis=1, inplace=True)

# %%
game_df.shape
# Out:
# (52, 45)

# %%
game_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   week                     52 non-null     int64
#  1   special_sale             52 non-null     float64
#  2   Payday                   52 non-null     float64
#  3   Max Temp (°C)            52 non-null     float64
#  4   Min Temp (°C)            52 non-null     float64
#  5   Mean Temp (°C)           52 non-null     float64
#  6   Heat Deg Days (°C)       52 non-null     float64
#  7   Cool Deg Days (°C)       52 non-null     float64
#  8   Total Rain (mm)          52 non-null     float64
#  9   Total Snow (cm)          52 non-null     float64
#  10  Total Precip (mm)        52 non-null     float64
#  11  Snow on Grnd (cm)        52 non-null     float64
#  12  NPS                      52 non-null     float64
#  13  Stock_Index              52 non-null     float64
#  14  Total Investment         52 non-null     float64
#  15  TV                       52 non-null     float64
#  16  Digital                  52 non-null     float64
#  17  Sponsorship              52 non-null     float64
#  18  Content                  52 non-null     float64
#  19  Online                   52 non-null     float64
#  20  Affiliates               52 non-null     float64
#  21  SEM                      52 non-null     float64
#  22  Radio                    52 non-null     float64
#  23  Other                    52 non-null     float64
#  24  TV_adstock               52 non-null     float64
#  25  Digital_adstock          52 non-null     float64
#  26  Sponsorship_adstock      52 non-null     float64
#  27  Content_adstock          52 non-null     float64
#  28  Online_adstock           52 non-null     float64
#  29  Affiliates_adstock       52 non-null     float64
#  30  SEM_adstock              52 non-null     float64
#  31  Radio_adstock            52 non-null     float64
#  32  Other_adstock            52 non-null     float64
#  33  order_id                 52 non-null     int64
#  34  order_item_id            52 non-null     int64
#  35  sla                      52 non-null     float64
#  36  product_procurement_sla  52 non-null     float64
#  37  product_mrp              52 non-null     float64
#  38  units                    52 non-null     int64
#  39  gmv                      52 non-null     float64
#  40  listed_price             52 non-null     float64
#  41  discount_percent         52 non-null     float64
#  42  total_price              52 non-null     float64
#  43  COD                      52 non-null     int64
#  44  luxury_product           52 non-null     int64
# dtypes: float64(39), int64(6)
# memory usage: 18.4 KB

# %%
# Null Values

game_df.isna().sum()
# Out:
# week                       0
# special_sale               0
# Payday                     0
# Max Temp (°C)              0
# Min Temp (°C)              0
# Mean Temp (°C)             0
# Heat Deg Days (°C)         0
# Cool Deg Days (°C)         0
# Total Rain (mm)            0
# Total Snow (cm)            0
# Total Precip (mm)          0
# Snow on Grnd (cm)          0
# NPS                        0
# Stock_Index                0
# Total Investment           0
# TV                         0
# Digital                    0
# Sponsorship                0
# Content                    0
# Online                     0
# Affiliates                 0
# SEM                        0
# Radio                      0
# Other                      0
# TV_adstock                 0
# Digital_adstock            0
# Sponsorship_adstock        0
# Content_adstock            0
# Online_adstock             0
# Affiliates_adstock         0
# SEM_adstock                0
# Radio_adstock              0
# Other_adstock              0
# order_id                   0
# order_item_id              0
# sla                        0
# product_procurement_sla    0
# product_mrp                0
# units                      0
# gmv                        0
# listed_price               0
# discount_percent           0
# total_price                0
# COD                        0
# luxury_product             0
# dtype: int64

# %%
game_df.columns
# Out:
# Index(['week', 'special_sale', 'Payday', 'Max Temp (°C)', 'Min Temp (°C)',
#        'Mean Temp (°C)', 'Heat Deg Days (°C)', 'Cool Deg Days (°C)',
#        'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
#        'Snow on Grnd (cm)', 'NPS', 'Stock_Index', 'Total Investment', 'TV',
#        'Digital', 'Sponsorship', 'Content', 'Online', 'Affiliates', 'SEM',
#        'Radio', 'Other', 'TV_adstock', 'Digital_adstock',
#        'Sponsorship_adstock', 'Content_adstock', 'Online_adstock',
#        'Affiliates_adstock', 'SEM_adstock', 'Radio_adstock', 'Other_adstock',
#        'order_id', 'order_item_id', 'sla', 'product_procurement_sla',
#        'product_mrp', 'units', 'gmv', 'listed_price', 'discount_percent',
#        'total_price', 'COD', 'luxury_product'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
game_df.columns
# Out:
# Index(['week', 'special_sale', 'Payday', 'Max Temp (°C)', 'Min Temp (°C)',
#        'Mean Temp (°C)', 'Heat Deg Days (°C)', 'Cool Deg Days (°C)',
#        'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
#        'Snow on Grnd (cm)', 'NPS', 'Stock_Index', 'Total Investment', 'TV',
#        'Digital', 'Sponsorship', 'Content', 'Online', 'Affiliates', 'SEM',
#        'Radio', 'Other', 'TV_adstock', 'Digital_adstock',
#        'Sponsorship_adstock', 'Content_adstock', 'Online_adstock',
#        'Affiliates_adstock', 'SEM_adstock', 'Radio_adstock', 'Other_adstock',
#        'order_id', 'order_item_id', 'sla', 'product_procurement_sla',
#        'product_mrp', 'units', 'gmv', 'listed_price', 'discount_percent',
#        'total_price', 'COD', 'luxury_product'],
#       dtype='object')

# %%
# Sepearating the KPI's to their categories

pricing_kpi =  ['product_mrp', 'units', 'gmv', 'listed_price', 'discount_percent', 'total_price', 'special_sale', 'Payday', 'COD']
adv_kpi =      ['TV', 'Digital', 'Sponsorship', 'Content', 'Online', 'Affiliates', 'SEM', 'Radio', 'Other'] 
ad_stock_kpi = ['TV_adstock', 'Digital_adstock', 'Sponsorship_adstock',  'Content_adstock', 'Online_adstock',
                'Affiliates_adstock', 'SEM_adstock', 'Radio_adstock', 'Other_adstock']
other_kpi =        ['sla', 'product_procurement_sla', 'NPS', 'Stock_Index']
climate_Kpi =  ['Max Temp (°C)', 'Min Temp (°C)', 'Mean Temp (°C)', 'Heat Deg Days (°C)', 'Cool Deg Days (°C)',
               'Total Rain (mm)',  'Total Snow (cm)', 'Total Precip (mm)', 'Snow on Grnd (cm)']

# %%
# Reodering the important KPI's

cols = ['week', 'product_mrp', 'units', 'gmv', 'listed_price', 'discount_percent', 'total_price', 'special_sale', 'Payday', 'COD',
        'TV_adstock', 'Digital_adstock', 'Sponsorship_adstock',  'Content_adstock', 'Online_adstock','Affiliates_adstock', 
        'SEM_adstock', 'Radio_adstock', 'Other_adstock', 'sla', 'product_procurement_sla', 'NPS', 'Stock_Index', 
        'Max Temp (°C)', 'Min Temp (°C)', 'Mean Temp (°C)', 
        'Heat Deg Days (°C)', 'Cool Deg Days (°C)', 'Total Rain (mm)',  'Total Snow (cm)', 'Total Precip (mm)', 
        'Snow on Grnd (cm)']

# %%
game_df = game_df[cols]
game_df.head()
# Out:
#    week  product_mrp  units     gmv  listed_price  discount_percent  \
# 0     1      666.421      1 499.368       499.368            22.860
# 1     2      894.309      1 467.896       467.896            42.474
# 2     3      668.555      1 380.714       380.714            43.572
# 3     4      800.160      1 489.387       489.387            35.986
# 4     5      783.811      1 483.509       483.509            36.695
#
#    total_price  special_sale  Payday   COD  TV_adstock  Digital_adstock  \
# 0      666.421         0.000   0.200     0       0.054            0.633
# 1      894.309         0.000   0.000  1730       0.081            0.950
# 2      668.555         0.286   0.143  1622       0.081            0.950
# 3      800.160         0.000   0.000  1406       0.081            0.950
# 4      783.811         0.000   0.143   921       0.028            0.572
#
#    Sponsorship_adstock  Content_adstock  Online_adstock  Affiliates_adstock  \
# 0                1.854            0.000           0.332               0.137
# 1                2.780            0.000           0.498               0.205
# 2                2.780            0.000           0.498               0.205
# 3                2.780            0.000           0.498               0.205
# 4                1.139            0.000           0.192               0.083
#
#    SEM_adstock  Radio_adstock  Other_adstock   sla  product_procurement_sla  \
# 0        1.256          0.000          0.000 4.158                    2.526
# 1        1.884          0.000          0.000 5.293                    3.120
# 2        1.884          0.000          0.000 5.221                    2.589
# 3        1.884          0.000          0.000 5.252                    2.401
# 4        1.131          0.000          0.000 5.682                    2.332
#
#      NPS  Stock_Index  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0 54.600     1177.000         25.500         13.200          19.360
# 1 54.600     1177.000         24.025         14.385          19.263
# 2 54.600     1177.000         27.383         16.314          21.906
# 3 54.600     1177.000         28.240         14.342          20.540
# 4 56.139     1185.286         29.811         16.242          23.092
#
#    Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  Total Snow (cm)  \
# 0               0.100               1.460            0.000            0.000
# 1               1.059               2.322            4.155            0.029
# 2               0.816               4.722            1.569            0.029
# 3               1.632               4.172            1.141            0.029
# 4               0.816               5.908            4.341            0.029
#
#    Total Precip (mm)  Snow on Grnd (cm)
# 0              0.000              0.000
# 1              4.184              0.041
# 2              1.598              0.041
# 3              1.170              0.041
# 4              4.370              0.041

# %%
# Converting the bi-categorical features to binary feature

game_df['Payday'] = game_df['Payday'].apply(lambda x: 1 if x>0 else 0)
game_df['special_sale'] = game_df['special_sale'].apply(lambda x: 1 if x>0 else 0)

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Seeing the distribution of the different numeric features

# %%
# Price related features

features = ['sla', 'product_procurement_sla', 'product_mrp', 'units', 
            'gmv', 'listed_price', 'discount_percent', 'total_price']

plt.figure(figsize=(12,10))
for i, col in enumerate(features):
  plt.subplot(4, 2, i+1)
  sns.distplot(game_df[col])

plt.tight_layout()

# %% [markdown]
# * Most of the features are noramlly distribted
# * Most of the products high selling gaming products are in the price range - 700 to 900

# %%
# Climate Related features

features =  ['Max Temp (°C)', 'Min Temp (°C)', 'Mean Temp (°C)',
       'Heat Deg Days (°C)', 'Cool Deg Days (°C)', 'Total Rain (mm)',
       'Total Snow (cm)', 'Total Precip (mm)', 'Snow on Grnd (cm)']

plt.figure(figsize=(12,10))
for i, col in enumerate(features):
  plt.subplot(3, 3, i+1)
  sns.distplot(game_df[col])

plt.tight_layout()

# %% [markdown]
# *   All the climate realated features are normally distributed
# *   Though the year of time, the average rainfall is about 2.5mm
# *   The average temperature is about 13 degree C, which makes it a cool country
# *   Being the coldest country there is much snowfall in the Ontario

# %%
# Advertising or Marketing related

features =  [  'TV_adstock', 'Digital_adstock', 'Sponsorship_adstock',  'Content_adstock', 'Online_adstock',
                'Affiliates_adstock', 'SEM_adstock', 'Radio_adstock', 'Other_adstock']
plt.figure(figsize=(12,10))
for i, col in enumerate(features):
  plt.subplot(3, 3, i+1)
  sns.distplot(game_df[col])

plt.tight_layout()

# %% [markdown]
# *   TV adstock has less impression for the Camera products about 2 days, which is unusual
#
# *   Sponsorship and online has higher impression of about 7to8 days then any other

# %% [markdown]
# ## Bi-Variate Analysis

# %% [markdown]
# ### Behavior / trend of the various features over the weeks

# %%
# # order_id and order_item_id over the week

# features = ['order_id', 'order_item_id']

# plt.figure(figsize=(12,10))
# for i, col in enumerate(features):
#   plt.subplot(2, 1, i+1)
#   sns.barplot(game_df['week'], game_df[col])

# plt.tight_layout()

# %%
pricing_kpi
# Out:
# ['product_mrp',
#  'units',
#  'gmv',
#  'listed_price',
#  'discount_percent',
#  'total_price',
#  'special_sale',
#  'Payday',
#  'COD']

# %%
# GMV, Sale, discount, listed_price, total_price, SLA over the different weeks

features = ['gmv', 'product_mrp', 'listed_price', 'total_price', 'discount_percent', 'units',
            'special_sale', 'Payday', 'COD']

for col in features:
  plt.figure(figsize=(12, 7))
  sns.lineplot(game_df['week'], game_df[col])
  plt.show()

# %% [markdown]
# *   On the 18th week there is steep increase in the COD order and, between 41 and 43 their steep fall in COD orders
# *   The gaming products are good enough generating proper gmv through the year period campare to the other two

# %%
# NPS, stock_index over the weeks

features = ['NPS', 'Stock_Index']

plt.figure(figsize=(12,10))
for i, col in enumerate(features):
  plt.subplot(2, 1, i+1)
  sns.lineplot(game_df['week'], game_df[col])

plt.tight_layout()

# %% [markdown]
# Between 6th and 10th week the brand value or nps of the company is good

# %%
# COD over the weeks

features = ['COD']
plt.figure(figsize=(12,10))
for i, col in enumerate(features):
  plt.subplot(2, 1, i+1)
  sns.lineplot(game_df['week'], game_df[col])

plt.tight_layout()

# %%
# Correlation feturewise


kpis = [pricing_kpi, ad_stock_kpi, climate_Kpi, other_kpi]

for k in kpis:
  # plt.figure(figsize=())
  sns.heatmap(game_df[k].corr(), cmap='inferno', annot=True)
  plt.show()

# %%
# Correlation of the important features

plt.figure(figsize=(15, 12))
sns.heatmap(game_df.corr(), cmap='inferno')
plt.show()

# %%
game_df.columns
# Out:
# Index(['week', 'product_mrp', 'units', 'gmv', 'listed_price',
#        'discount_percent', 'total_price', 'special_sale', 'Payday', 'COD',
#        'TV_adstock', 'Digital_adstock', 'Sponsorship_adstock',
#        'Content_adstock', 'Online_adstock', 'Affiliates_adstock',
#        'SEM_adstock', 'Radio_adstock', 'Other_adstock', 'sla',
#        'product_procurement_sla', 'NPS', 'Stock_Index', 'Max Temp (°C)',
#        'Min Temp (°C)', 'Mean Temp (°C)', 'Heat Deg Days (°C)',
#        'Cool Deg Days (°C)', 'Total Rain (mm)', 'Total Snow (cm)',
#        'Total Precip (mm)', 'Snow on Grnd (cm)'],
#       dtype='object')

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Mutiple Linear Regression

# %%
game_df.head()
# Out:
#    week  product_mrp  units     gmv  listed_price  discount_percent  \
# 0     1      666.421      1 499.368       499.368            22.860
# 1     2      894.309      1 467.896       467.896            42.474
# 2     3      668.555      1 380.714       380.714            43.572
# 3     4      800.160      1 489.387       489.387            35.986
# 4     5      783.811      1 483.509       483.509            36.695
#
#    total_price  special_sale  Payday   COD  TV_adstock  Digital_adstock  \
# 0      666.421             0       1     0       0.054            0.633
# 1      894.309             0       0  1730       0.081            0.950
# 2      668.555             1       1  1622       0.081            0.950
# 3      800.160             0       0  1406       0.081            0.950
# 4      783.811             0       1   921       0.028            0.572
#
#    Sponsorship_adstock  Content_adstock  Online_adstock  Affiliates_adstock  \
# 0                1.854            0.000           0.332               0.137
# 1                2.780            0.000           0.498               0.205
# 2                2.780            0.000           0.498               0.205
# 3                2.780            0.000           0.498               0.205
# 4                1.139            0.000           0.192               0.083
#
#    SEM_adstock  Radio_adstock  Other_adstock   sla  product_procurement_sla  \
# 0        1.256          0.000          0.000 4.158                    2.526
# 1        1.884          0.000          0.000 5.293                    3.120
# 2        1.884          0.000          0.000 5.221                    2.589
# 3        1.884          0.000          0.000 5.252                    2.401
# 4        1.131          0.000          0.000 5.682                    2.332
#
#      NPS  Stock_Index  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0 54.600     1177.000         25.500         13.200          19.360
# 1 54.600     1177.000         24.025         14.385          19.263
# 2 54.600     1177.000         27.383         16.314          21.906
# 3 54.600     1177.000         28.240         14.342          20.540
# 4 56.139     1185.286         29.811         16.242          23.092
#
#    Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  Total Snow (cm)  \
# 0               0.100               1.460            0.000            0.000
# 1               1.059               2.322            4.155            0.029
# 2               0.816               4.722            1.569            0.029
# 3               1.632               4.172            1.141            0.029
# 4               0.816               5.908            4.341            0.029
#
#    Total Precip (mm)  Snow on Grnd (cm)
# 0              0.000              0.000
# 1              4.184              0.041
# 2              1.598              0.041
# 3              1.170              0.041
# 4              4.370              0.041

# %% [markdown]
# ### Pre-Processing

# %% [markdown]
# Lets build the simple Linear Regression model with the most important features

# %%
game_df.columns.values
# Out:
# array(['week', 'product_mrp', 'units', 'gmv', 'listed_price',
#        'discount_percent', 'total_price', 'special_sale', 'Payday', 'COD',
#        'TV_adstock', 'Digital_adstock', 'Sponsorship_adstock',
#        'Content_adstock', 'Online_adstock', 'Affiliates_adstock',
#        'SEM_adstock', 'Radio_adstock', 'Other_adstock', 'sla',
#        'product_procurement_sla', 'NPS', 'Stock_Index', 'Max Temp (°C)',
#        'Min Temp (°C)', 'Mean Temp (°C)', 'Heat Deg Days (°C)',
#        'Cool Deg Days (°C)', 'Total Rain (mm)', 'Total Snow (cm)',
#        'Total Precip (mm)', 'Snow on Grnd (cm)'], dtype=object)

# %%
# Dropping the unimportant or the columns which doesn't have much use to our model building

game_df.drop(columns=['week', 'Stock_Index', 'Max Temp (°C)', 'Min Temp (°C)', 'Total Rain (mm)'], axis =1, inplace=True)

# %% [markdown]
# #### Dummy variable creation

# %%
# Dummy Variable creation
game_df.select_dtypes('O').columns
# Out:
# Index([], dtype='object')

# %% [markdown]
# No need to create the dummy variables as there are no categorical variable

# %% [markdown]
# #### Train-Test Split

# %%
# Test-Train Split

from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(game_df, train_size = 0.7, test_size = 0.3, random_state = 100)

# %% [markdown]
# #### Feature Scaling

# %%
df_train.head()
# Out:
#     product_mrp  units     gmv  listed_price  discount_percent  total_price  \
# 40      778.831      1 414.494       414.494            42.357      778.831
# 44      748.368      1 387.118       387.118            44.315      748.368
# 37      749.650      1 407.388       407.388            41.418      749.650
# 17      749.114      1 401.849       401.849            44.738      749.114
# 7       549.000      1 295.667       295.667            45.460      549.000
#
#     special_sale  Payday   COD  TV_adstock  Digital_adstock  \
# 40             0       0   145       1.952            0.327
# 44             0       0  2052       0.411            0.231
# 37             0       1  2053       3.488            0.788
# 17             0       1  2481       1.612            1.833
# 7              1       0     3       0.002            0.383
#
#     Sponsorship_adstock  Content_adstock  Online_adstock  Affiliates_adstock  \
# 40                9.116            0.013           6.193               2.135
# 44                9.504            0.237           7.095               2.040
# 37               15.596            0.139           6.914               2.332
# 17               13.418            0.464           6.959               2.191
# 7                 0.319            0.000           0.039               0.022
#
#     SEM_adstock  Radio_adstock  Other_adstock   sla  product_procurement_sla  \
# 40        1.582          0.000          0.000 6.261                    2.545
# 44        2.073          0.330          1.496 5.990                    2.327
# 37        1.948          0.326          5.980 6.011                    2.580
# 17        5.035          0.000          0.000 5.970                    2.199
# 7         0.754          0.000          0.000 3.000                    2.000
#
#       NPS  Mean Temp (°C)  Heat Deg Days (°C)  Cool Deg Days (°C)  \
# 40 51.828           6.818              12.019               0.837
# 44 47.307          12.583               5.975               0.558
# 37 49.021          11.189               7.648               0.837
# 17 44.770          13.287               6.109               1.395
# 7  59.987          22.134               0.816               4.950
#
#     Total Snow (cm)  Total Precip (mm)  Snow on Grnd (cm)
# 40            0.402              2.852              0.124
# 44            0.058              2.340              0.082
# 37            0.029              0.684              0.041
# 17            0.146              2.249              0.206
# 7             0.029              4.798              0.041

# %%
df_train.columns
# Out:
# Index(['product_mrp', 'units', 'gmv', 'listed_price', 'discount_percent',
#        'total_price', 'special_sale', 'Payday', 'COD', 'TV_adstock',
#        'Digital_adstock', 'Sponsorship_adstock', 'Content_adstock',
#        'Online_adstock', 'Affiliates_adstock', 'SEM_adstock', 'Radio_adstock',
#        'Other_adstock', 'sla', 'product_procurement_sla', 'NPS',
#        'Mean Temp (°C)', 'Heat Deg Days (°C)', 'Cool Deg Days (°C)',
#        'Total Snow (cm)', 'Total Precip (mm)', 'Snow on Grnd (cm)'],
#       dtype='object')

# %%
# Min-Max Scaling

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df_train[df_train.columns] = scaler.fit_transform(df_train)
df_train.head()
# Out:
#     product_mrp  units   gmv  listed_price  discount_percent  total_price  \
# 40        0.600  0.000 0.626         0.626             0.434        0.600
# 44        0.521  0.000 0.489         0.489             0.567        0.521
# 37        0.524  0.000 0.590         0.590             0.370        0.524
# 17        0.523  0.000 0.562         0.562             0.596        0.523
# 7         0.000  0.000 0.032         0.032             0.645        0.000
#
#     special_sale  Payday   COD  TV_adstock  Digital_adstock  \
# 40         0.000   0.000 0.020       0.559            0.041
# 44         0.000   0.000 0.290       0.117            0.020
# 37         0.000   1.000 0.290       1.000            0.142
# 17         0.000   1.000 0.351       0.462            0.369
# 7          1.000   0.000 0.000       0.000            0.054
#
#     Sponsorship_adstock  Content_adstock  Online_adstock  Affiliates_adstock  \
# 40                0.280            0.010           0.676               0.815
# 44                0.292            0.184           0.775               0.778
# 37                0.486            0.107           0.755               0.891
# 17                0.417            0.359           0.760               0.836
# 7                 0.000            0.000           0.000               0.000
#
#     SEM_adstock  Radio_adstock  Other_adstock   sla  product_procurement_sla  \
# 40        0.074          0.000          0.000 0.884                    0.495
# 44        0.118          0.407          0.184 0.810                    0.304
# 37        0.106          0.403          0.736 0.816                    0.526
# 17        0.382          0.000          0.000 0.805                    0.192
# 7         0.000          0.000          0.000 0.000                    0.017
#
#      NPS  Mean Temp (°C)  Heat Deg Days (°C)  Cool Deg Days (°C)  \
# 40 0.477           0.017               0.952               0.142
# 44 0.187           0.365               0.439               0.094
# 37 0.297           0.281               0.581               0.142
# 17 0.024           0.408               0.450               0.236
# 7  1.000           0.942               0.000               0.838
#
#     Total Snow (cm)  Total Precip (mm)  Snow on Grnd (cm)
# 40            0.343              0.283              0.027
# 44            0.027              0.224              0.018
# 37            0.000              0.033              0.009
# 17            0.108              0.214              0.045
# 7             0.000              0.508              0.009

# %% [markdown]
# #### Splitting X-train and Y-train

# %%
# Splitting X-train and Y-train

y_train = df_train.pop('gmv')
x_train = df_train

# %% [markdown]
# ### Model Building

# %%
x_train.shape
# Out:
# (36, 26)

# %% [markdown]
# #### RFE - Recursive Feature Elimination

# %%
# Importing RFE and LinearRegression

from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
# Running RFE with the output number of the variable equal to 10
lm = LinearRegression()
lm.fit(x_train, y_train)

rfe = RFE(lm, 10)             # running RFE
rfe = rfe.fit(x_train, y_train)

# %%
list(zip(x_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('product_mrp', False, 16),
#  ('units', False, 15),
#  ('listed_price', True, 1),
#  ('discount_percent', False, 14),
#  ('total_price', False, 11),
#  ('special_sale', True, 1),
#  ('Payday', False, 17),
#  ('COD', True, 1),
#  ('TV_adstock', True, 1),
#  ('Digital_adstock', False, 9),
#  ('Sponsorship_adstock', False, 12),
#  ('Content_adstock', False, 2),
#  ('Online_adstock', False, 6),
#  ('Affiliates_adstock', False, 10),
#  ('SEM_adstock', False, 8),
#  ('Radio_adstock', True, 1),
#  ('Other_adstock', False, 7),
#  ('sla', False, 4),
#  ('product_procurement_sla', False, 3),
#  ('NPS', True, 1),
#  ('Mean Temp (°C)', True, 1),
#  ('Heat Deg Days (°C)', True, 1),
#  ('Cool Deg Days (°C)', False, 13),
#  ('Total Snow (cm)', True, 1),
#  ('Total Precip (mm)', False, 5),
#  ('Snow on Grnd (cm)', True, 1)]

# %%
# Extracting the RFE supported columns or top 20 features for our model building

col = x_train.columns[rfe.support_].values
col
# Out:
# array(['listed_price', 'special_sale', 'COD', 'TV_adstock',
#        'Radio_adstock', 'NPS', 'Mean Temp (°C)', 'Heat Deg Days (°C)',
#        'Total Snow (cm)', 'Snow on Grnd (cm)'], dtype=object)

# %%
# Unimportant columns which got eliminated through RFE

x_train.columns[~rfe.support_]
# Out:
# Index(['product_mrp', 'units', 'discount_percent', 'total_price', 'Payday',
#        'Digital_adstock', 'Sponsorship_adstock', 'Content_adstock',
#        'Online_adstock', 'Affiliates_adstock', 'SEM_adstock', 'Other_adstock',
#        'sla', 'product_procurement_sla', 'Cool Deg Days (°C)',
#        'Total Precip (mm)'],
#       dtype='object')

# %% [markdown]
# #### Statsmodel - for the detailed statistics

# %% [markdown]
# ##### Model 1

# %%
# Creating X_test dataframe with RFE selected variables

x_train_rfe = x_train[col]

# %%
# Adding a constant variable & importing the stats model

import statsmodels.api as sm  
x_train_rfe = sm.add_constant(x_train_rfe)

# %%
lm = sm.OLS(y_train,x_train_rfe).fit()   # Running the linear model

# %%
#Statistical summary of our linear model

print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.046e+29
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):               0.00
# Time:                        13:21:15   Log-Likelihood:                 1190.9
# No. Observations:                  36   AIC:                            -2360.
# Df Residuals:                      25   BIC:                            -2342.
# Df Model:                          10
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -4.441e-16   3.57e-15     -0.125      0.902   -7.79e-15     6.9e-15
# listed_price           1.0000   1.26e-15   7.93e+14      0.000       1.000       1.000
# special_sale        2.776e-17   6.98e-16      0.040      0.969   -1.41e-15    1.47e-15
# COD                 -1.11e-16   1.77e-15     -0.063      0.950   -3.75e-15    3.53e-15
# TV_adstock           2.22e-16   1.24e-15      0.178      0.860   -2.34e-15    2.78e-15
# Radio_adstock       2.914e-16   8.28e-16      0.352      0.728   -1.41e-15       2e-15
# NPS                 5.551e-16    1.5e-15      0.370      0.714   -2.53e-15    3.64e-15
# Mean Temp (°C)     -4.441e-16   4.29e-15     -0.104      0.918   -9.28e-15    8.39e-15
# Heat Deg Days (°C) -1.776e-15   4.09e-15     -0.434      0.668   -1.02e-14    6.65e-15
# Total Snow (cm)    -1.665e-16   1.32e-15     -0.126      0.901   -2.89e-15    2.55e-15
# Snow on Grnd (cm)   -1.11e-16   1.66e-15     -0.067      0.947   -3.53e-15    3.31e-15
# ==============================================================================
# Omnibus:                        1.956   Durbin-Watson:                   0.336
# Prob(Omnibus):                  0.376   Jarque-Bera (JB):                1.178
# Skew:                           0.053   Prob(JB):                        0.555
# Kurtosis:                       2.120   Cond. No.                         48.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
x = x_train_rfe
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#               Features     VIF
# 0                const 293.420
# 7       Mean Temp (°C)  31.790
# 8   Heat Deg Days (°C)  31.170
# 6                  NPS   3.460
# 4           TV_adstock   2.470
# 3                  COD   2.300
# 9      Total Snow (cm)   1.970
# 2         special_sale   1.940
# 10   Snow on Grnd (cm)   1.700
# 1         listed_price   1.660
# 5        Radio_adstock   1.650

# %% [markdown]
# ##### Model 2

# %%
# Dropping the column Mean Temp (°C)	

x_train_new = x_train_rfe.drop('Mean Temp (°C)', axis=1)

# %%
# Adding a constant variable
x_train_lm = sm.add_constant(x_train_new)
lm = sm.OLS(y_train,x_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.712e+28
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):               0.00
# Time:                        13:21:15   Log-Likelihood:                 1164.0
# No. Observations:                  36   AIC:                            -2308.
# Df Residuals:                      26   BIC:                            -2292.
# Df Model:                           9
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               1.832e-15   2.92e-15      0.627      0.536   -4.17e-15    7.84e-15
# listed_price           1.0000   2.53e-15   3.95e+14      0.000       1.000       1.000
# special_sale        5.551e-17   1.43e-15      0.039      0.969   -2.89e-15       3e-15
# COD                 -1.11e-16   3.63e-15     -0.031      0.976   -7.58e-15    7.36e-15
# TV_adstock          2.776e-16   2.48e-15      0.112      0.912   -4.81e-15    5.37e-15
# Radio_adstock        2.22e-16   1.71e-15      0.130      0.898    -3.3e-15    3.74e-15
# NPS                -2.082e-16   2.96e-15     -0.070      0.945    -6.3e-15    5.88e-15
# Heat Deg Days (°C)  3.053e-16   2.89e-15      0.106      0.917   -5.63e-15    6.24e-15
# Total Snow (cm)    -5.551e-17   2.72e-15     -0.020      0.984   -5.65e-15    5.54e-15
# Snow on Grnd (cm)           0   3.41e-15          0      1.000   -7.01e-15    7.01e-15
# ==============================================================================
# Omnibus:                        1.099   Durbin-Watson:                   0.017
# Prob(Omnibus):                  0.577   Jarque-Bera (JB):                1.005
# Skew:                           0.380   Prob(JB):                        0.605
# Kurtosis:                       2.697   Cond. No.                         17.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
x = x_train_new
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#              Features    VIF
# 0               const 45.920
# 7  Heat Deg Days (°C)  3.620
# 6                 NPS  3.150
# 4          TV_adstock  2.280
# 3                 COD  2.270
# 8     Total Snow (cm)  1.960
# 2        special_sale  1.910
# 9   Snow on Grnd (cm)  1.670
# 5       Radio_adstock  1.650
# 1        listed_price  1.570

# %% [markdown]
# ##### Model 3

# %%
# Dropping Snow on Grnd (cm)	 which has high VIF / p-value

x_train_new = x_train_new.drop(['Snow on Grnd (cm)'], axis=1)

# Adding a constant variable
x_train_lm = sm.add_constant(x_train_new)
lm = sm.OLS(y_train,x_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.779e+29
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):               0.00
# Time:                        13:21:15   Log-Likelihood:                 1195.0
# No. Observations:                  36   AIC:                            -2372.
# Df Residuals:                      27   BIC:                            -2358.
# Df Model:                           8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -3.886e-16   1.19e-15     -0.327      0.746   -2.83e-15    2.05e-15
# listed_price           1.0000   1.04e-15   9.65e+14      0.000       1.000       1.000
# special_sale        2.776e-16   5.93e-16      0.468      0.643   -9.39e-16    1.49e-15
# COD                  1.11e-16   1.49e-15      0.075      0.941   -2.94e-15    3.16e-15
# TV_adstock          4.441e-16   9.84e-16      0.451      0.655   -1.57e-15    2.46e-15
# Radio_adstock               0   6.93e-16          0      1.000   -1.42e-15    1.42e-15
# NPS                 4.857e-16   1.22e-15      0.398      0.694   -2.02e-15    2.99e-15
# Heat Deg Days (°C)  5.551e-17   1.04e-15      0.053      0.958   -2.08e-15     2.2e-15
# Total Snow (cm)     5.551e-17   1.06e-15      0.052      0.959   -2.13e-15    2.24e-15
# ==============================================================================
# Omnibus:                        2.396   Durbin-Watson:                   0.135
# Prob(Omnibus):                  0.302   Jarque-Bera (JB):                2.137
# Skew:                           0.504   Prob(JB):                        0.343
# Kurtosis:                       2.362   Cond. No.                         16.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model

vif = pd.DataFrame()
x = x_train_new
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#              Features    VIF
# 0               const 44.320
# 6                 NPS  3.110
# 7  Heat Deg Days (°C)  2.750
# 3                 COD  2.210
# 4          TV_adstock  2.100
# 2        special_sale  1.900
# 8     Total Snow (cm)  1.740
# 5       Radio_adstock  1.580
# 1        listed_price  1.530

# %% [markdown]
# ##### Model 4

# %%
# Dropping Radio_adstock which has high VIF / P-Value

x_train_new = x_train_new.drop(['Radio_adstock'], axis=1)

# Adding a constant variable
x_train_lm = sm.add_constant(x_train_new)
lm = sm.OLS(y_train,x_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.677e+29
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):               0.00
# Time:                        13:21:15   Log-Likelihood:                 1199.3
# No. Observations:                  36   AIC:                            -2383.
# Df Residuals:                      28   BIC:                            -2370.
# Df Model:                           7
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -3.608e-16   1.03e-15     -0.351      0.728   -2.47e-15    1.75e-15
# listed_price           1.0000   8.57e-16   1.17e+15      0.000       1.000       1.000
# special_sale         1.11e-16   4.89e-16      0.227      0.822   -8.91e-16    1.11e-15
# COD                 -2.22e-16    1.3e-15     -0.171      0.865   -2.88e-15    2.43e-15
# TV_adstock           1.11e-16   8.21e-16      0.135      0.893   -1.57e-15    1.79e-15
# NPS                 5.135e-16   1.05e-15      0.488      0.629   -1.64e-15    2.67e-15
# Heat Deg Days (°C)  6.106e-16   8.21e-16      0.744      0.463   -1.07e-15    2.29e-15
# Total Snow (cm)    -5.551e-17   9.26e-16     -0.060      0.953   -1.95e-15    1.84e-15
# ==============================================================================
# Omnibus:                        1.397   Durbin-Watson:                   0.142
# Prob(Omnibus):                  0.497   Jarque-Bera (JB):                1.002
# Skew:                          -0.066   Prob(JB):                        0.606
# Kurtosis:                       2.193   Cond. No.                         16.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model

vif = pd.DataFrame()
x = x_train_new
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#              Features    VIF
# 0               const 43.710
# 5                 NPS  3.050
# 6  Heat Deg Days (°C)  2.250
# 3                 COD  2.210
# 4          TV_adstock  1.920
# 7     Total Snow (cm)  1.740
# 2        special_sale  1.710
# 1        listed_price  1.380

# %% [markdown]
# ##### Model 5

# %%
# Dropping Total Snow (cm)	which has high P-Value

x_train_new = x_train_new.drop(['Total Snow (cm)'], axis=1)

# Adding a constant variable
x_train_lm = sm.add_constant(x_train_new)
lm = sm.OLS(y_train,x_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.636e+30
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):               0.00
# Time:                        13:21:15   Log-Likelihood:                 1247.2
# No. Observations:                  36   AIC:                            -2480.
# Df Residuals:                      29   BIC:                            -2469.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const              -4.163e-16   2.65e-16     -1.573      0.127   -9.58e-16    1.25e-16
# listed_price           1.0000   2.22e-16    4.5e+15      0.000       1.000       1.000
# special_sale       -3.608e-16   1.26e-16     -2.873      0.008   -6.18e-16   -1.04e-16
# COD                 5.967e-16   3.27e-16      1.822      0.079   -7.31e-17    1.27e-15
# TV_adstock          3.331e-16   2.09e-16      1.596      0.121   -9.37e-17     7.6e-16
# NPS                 5.274e-16   2.69e-16      1.961      0.060   -2.27e-17    1.08e-15
# Heat Deg Days (°C)   1.11e-16   1.69e-16      0.656      0.517   -2.35e-16    4.57e-16
# ==============================================================================
# Omnibus:                        0.824   Durbin-Watson:                   1.445
# Prob(Omnibus):                  0.662   Jarque-Bera (JB):                0.881
# Skew:                           0.250   Prob(JB):                        0.644
# Kurtosis:                       2.420   Cond. No.                         15.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model

vif = pd.DataFrame()
x = x_train_new
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#              Features    VIF
# 0               const 42.970
# 5                 NPS  2.960
# 3                 COD  2.100
# 4          TV_adstock  1.850
# 2        special_sale  1.670
# 6  Heat Deg Days (°C)  1.420
# 1        listed_price  1.370

# %% [markdown]
# ##### Model 6

# %%
# Dropping Total Snow (cm) which has high VIF / P-Value

x_train_new = x_train_new.drop(['Heat Deg Days (°C)'], axis=1)

# Adding a constant variable
x_train_lm = sm.add_constant(x_train_new)
lm = sm.OLS(y_train,x_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.050e+31
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):               0.00
# Time:                        13:21:15   Log-Likelihood:                 1258.1
# No. Observations:                  36   AIC:                            -2504.
# Df Residuals:                      30   BIC:                            -2495.
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -3.469e-16    1.9e-16     -1.830      0.077   -7.34e-16    4.03e-17
# listed_price     1.0000   1.61e-16   6.22e+15      0.000       1.000       1.000
# special_sale  1.665e-16   8.88e-17      1.876      0.070   -1.48e-17    3.48e-16
# COD           2.082e-16   2.37e-16      0.877      0.387   -2.77e-16    6.93e-16
# TV_adstock    -1.11e-16   1.39e-16     -0.801      0.430   -3.94e-16    1.72e-16
# NPS           4.857e-16   1.96e-16      2.481      0.019    8.59e-17    8.86e-16
# ==============================================================================
# Omnibus:                        0.450   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.798   Jarque-Bera (JB):                0.437
# Skew:                          -0.239   Prob(JB):                        0.804
# Kurtosis:                       2.748   Cond. No.                         15.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model

vif = pd.DataFrame()
x = x_train_new
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#        Features    VIF
# 0         const 41.610
# 5           NPS  2.960
# 3           COD  2.080
# 2  special_sale  1.580
# 4    TV_adstock  1.540
# 1  listed_price  1.360

# %% [markdown]
# ##### Model 7

# %%
# Dropping TV_adstock which has high VIF / P-Value

x_train_new = x_train_new.drop(['TV_adstock'], axis=1)

# Adding a constant variable
x_train_lm = sm.add_constant(x_train_new)
lm = sm.OLS(y_train,x_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.195e+30
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):               0.00
# Time:                        13:21:15   Log-Likelihood:                 1236.9
# No. Observations:                  36   AIC:                            -2464.
# Df Residuals:                      31   BIC:                            -2456.
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -1.388e-16   2.74e-16     -0.507      0.616   -6.97e-16     4.2e-16
# listed_price     1.0000   2.82e-16   3.54e+15      0.000       1.000       1.000
# special_sale -3.608e-16   1.57e-16     -2.303      0.028    -6.8e-16   -4.13e-17
# COD          -4.718e-16   4.13e-16     -1.143      0.262   -1.31e-15     3.7e-16
# NPS          -2.776e-16   2.92e-16     -0.951      0.349   -8.73e-16    3.17e-16
# ==============================================================================
# Omnibus:                        9.351   Durbin-Watson:                   1.771
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                8.895
# Skew:                           1.205   Prob(JB):                       0.0117
# Kurtosis:                       3.347   Cond. No.                         12.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model

vif = pd.DataFrame()
x = x_train_new
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#        Features    VIF
# 0         const 27.720
# 4           NPS  2.100
# 3           COD  2.010
# 2  special_sale  1.570
# 1  listed_price  1.340

# %% [markdown]
# ##### Modle 8

# %%
# Dropping NPS which has high VIF / P-Value

x_train_new = x_train_new.drop(['NPS'], axis=1)

# Adding a constant variable
x_train_lm = sm.add_constant(x_train_new)
lm = sm.OLS(y_train,x_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.411e+30
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):               0.00
# Time:                        13:21:15   Log-Likelihood:                 1221.2
# No. Observations:                  36   AIC:                            -2434.
# Df Residuals:                      32   BIC:                            -2428.
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         2.082e-17   2.96e-16      0.070      0.944   -5.82e-16    6.24e-16
# listed_price     1.0000    4.2e-16   2.38e+15      0.000       1.000       1.000
# special_sale -1.665e-16   2.19e-16     -0.760      0.453   -6.13e-16     2.8e-16
# COD          -4.163e-16   4.78e-16     -0.872      0.390   -1.39e-15    5.56e-16
# ==============================================================================
# Omnibus:                        2.588   Durbin-Watson:                   0.123
# Prob(Omnibus):                  0.274   Jarque-Bera (JB):                1.421
# Skew:                           0.344   Prob(JB):                        0.491
# Kurtosis:                       3.688   Cond. No.                         8.58
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model

vif = pd.DataFrame()
x = x_train_new
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#        Features    VIF
# 0         const 13.970
# 2  special_sale  1.320
# 1  listed_price  1.280
# 3           COD  1.160

# %% [markdown]
# #### Residual Analysis of the train data
#
# So, now to check if the error terms are also normally distributed (which is infact, one of the major assumptions of linear regression), let us plot the histogram of the error terms and see what it looks like.

# %%
y_train_pred = lm.predict(x_train_lm)

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_pred), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)                         # X-label
# Out:
# Text(0.5, 0, 'Errors')

# %%
# RMSE
from sklearn.metrics import mean_squared_error

rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
rmse
# Out:
# 4.47942492152111e-16

# %% [markdown]
# #### Making Predictions

# %% [markdown]
# ##### Applying the scaling on the test sets

# %%
col = df_test.columns

# %%
df_test[col] = scaler.transform(df_test[col])

# %% [markdown]
# ##### Dividing into X_test and y_test

# %%
y_test = df_test.pop('gmv')
x_test = df_test

# %%
x_train_new.columns
# Out:
# Index(['const', 'listed_price', 'special_sale', 'COD'], dtype='object')

# %%
# Now let's use our model to make predictions.

# Creating X_test_new dataframe by dropping variables from X_test
x_test_new = x_test[['listed_price', 'SEM_adstock', 'COD']]

# Adding a constant variable 
x_test_new = sm.add_constant(x_test_new)

# %%
# Making predictions
y_pred = lm.predict(x_test_new)

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading 
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)                          # Y-label
# Out:
# Text(0, 0.5, 'y_pred')
