# %%
#supressing the warnings
import warnings
warnings.filterwarnings('ignore')

#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
# Setting display options for the rows and columns
pd.set_option('display.max_row', 200)
pd.set_option('display.max_columns', 100)
pd.set_option('display.float_format', '{:0.3f}'.format)

# %%
# Mounting the google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # 1. Data Reading and Understanding

# %%
# importing/reading the csv file
path = '/content/gdrive/MyDrive/E Commerce Capstone Project/Project FIles/camera_accessories.csv'
cam_df = pd.read_csv(path)
cam_df.head()
# Out:
#    Unnamed: 0  week  special_sale  Payday     Year  Month    Day  \
# 0           0     1         0.000   0.200 2015.000  7.000  3.000
# 1           1     2         0.000   0.000 2015.000  7.000  9.000
# 2           2     3         0.286   0.143 2015.000  7.000 16.000
# 3           3     4         0.000   0.000 2015.000  7.000 23.000
# 4           4     5         0.000   0.143 2015.000  7.286 21.143
#
#    Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  Heat Deg Days (°C)  \
# 0         25.500         13.200          19.360               0.100
# 1         24.025         14.385          19.263               1.059
# 2         27.383         16.314          21.906               0.816
# 3         28.240         14.342          20.540               1.632
# 4         29.811         16.242          23.092               0.816
#
#    Cool Deg Days (°C)  Total Rain (mm)  Total Snow (cm)  Total Precip (mm)  \
# 0               1.460            0.000            0.000              0.000
# 1               2.322            4.155            0.029              4.184
# 2               4.722            1.569            0.029              1.598
# 3               4.172            1.141            0.029              1.170
# 4               5.908            4.341            0.029              4.370
#
#    Snow on Grnd (cm)    NPS  Stock_Index  Total Investment    TV  Digital  \
# 0              0.000 54.600     1177.000             4.265 0.054    0.633
# 1              0.041 54.600     1177.000             4.265 0.054    0.633
# 2              0.041 54.600     1177.000             4.265 0.054    0.633
# 3              0.041 54.600     1177.000             4.265 0.054    0.633
# 4              0.041 56.139     1185.286             1.013 0.001    0.256
#
#    Sponsorship  Content  Online  Affiliates   SEM  Radio  Other  TV_adstock  \
# 0        1.854    0.000   0.332       0.137 1.256  0.000  0.000       0.054
# 1        1.854    0.000   0.332       0.137 1.256  0.000  0.000       0.081
# 2        1.854    0.000   0.332       0.137 1.256  0.000  0.000       0.081
# 3        1.854    0.000   0.332       0.137 1.256  0.000  0.000       0.081
# 4        0.213    0.000   0.026       0.015 0.503  0.000  0.000       0.028
#
#    Digital_adstock  Sponsorship_adstock  Content_adstock  Online_adstock  \
# 0            0.633                1.854            0.000           0.332
# 1            0.950                2.780            0.000           0.498
# 2            0.950                2.780            0.000           0.498
# 3            0.950                2.780            0.000           0.498
# 4            0.572                1.139            0.000           0.192
#
#    Affiliates_adstock  SEM_adstock  Radio_adstock  Other_adstock  order_id  \
# 0               0.137        1.256          0.000          0.000    24.000
# 1               0.205        1.884          0.000          0.000  2098.000
# 2               0.205        1.884          0.000          0.000  2243.000
# 3               0.205        1.884          0.000          0.000  2226.000
# 4               0.083        1.131          0.000          0.000  1483.000
#
#    order_item_id   sla  product_procurement_sla  product_mrp  units     gmv  \
# 0         24.000 3.208                    2.542      965.292  1.000 421.375
# 1       2130.000 7.366                    2.508      914.269  1.000 444.974
# 2       2268.000 6.716                    2.524      967.026  1.000 449.302
# 3       2256.000 6.770                    2.525      952.331  1.000 445.664
# 4       1507.000 6.639                    2.546      977.362  1.000 457.440
#
#    listed_price  discount_percent  total_price      COD  luxury_product
# 0       421.375            46.355      965.292    0.000           0.000
# 1       444.974            45.287      914.269 1459.000           0.000
# 2       449.302            45.778      967.026 1557.000           0.000
# 3       445.664            44.456      952.331 1591.000           0.000
# 4       457.440            44.936      977.362 1101.000           0.000

# %%
# Dropping  unimportant columns

cam_df.drop(columns=['Unnamed: 0', 'Year', 'Month', 'Day'], axis=1, inplace=True)

# %%
cam_df.shape
# Out:
# (52, 45)

# %%
cam_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   week                     52 non-null     int64
#  1   special_sale             52 non-null     float64
#  2   Payday                   52 non-null     float64
#  3   Max Temp (°C)            52 non-null     float64
#  4   Min Temp (°C)            52 non-null     float64
#  5   Mean Temp (°C)           52 non-null     float64
#  6   Heat Deg Days (°C)       52 non-null     float64
#  7   Cool Deg Days (°C)       52 non-null     float64
#  8   Total Rain (mm)          52 non-null     float64
#  9   Total Snow (cm)          52 non-null     float64
#  10  Total Precip (mm)        52 non-null     float64
#  11  Snow on Grnd (cm)        52 non-null     float64
#  12  NPS                      52 non-null     float64
#  13  Stock_Index              52 non-null     float64
#  14  Total Investment         52 non-null     float64
#  15  TV                       52 non-null     float64
#  16  Digital                  52 non-null     float64
#  17  Sponsorship              52 non-null     float64
#  18  Content                  52 non-null     float64
#  19  Online                   52 non-null     float64
#  20  Affiliates               52 non-null     float64
#  21  SEM                      52 non-null     float64
#  22  Radio                    52 non-null     float64
#  23  Other                    52 non-null     float64
#  24  TV_adstock               52 non-null     float64
#  25  Digital_adstock          52 non-null     float64
#  26  Sponsorship_adstock      52 non-null     float64
#  27  Content_adstock          52 non-null     float64
#  28  Online_adstock           52 non-null     float64
#  29  Affiliates_adstock       52 non-null     float64
#  30  SEM_adstock              52 non-null     float64
#  31  Radio_adstock            52 non-null     float64
#  32  Other_adstock            52 non-null     float64
#  33  order_id                 51 non-null     float64
#  34  order_item_id            51 non-null     float64
#  35  sla                      51 non-null     float64
#  36  product_procurement_sla  51 non-null     float64
#  37  product_mrp              51 non-null     float64
#  38  units                    51 non-null     float64
#  39  gmv                      51 non-null     float64
#  40  listed_price             51 non-null     float64
#  41  discount_percent         51 non-null     float64
#  42  total_price              51 non-null     float64
#  43  COD                      51 non-null     float64
#  44  luxury_product           51 non-null     float64
# dtypes: float64(44), int64(1)
# memory usage: 18.4 KB

# %%
# Treating the Null values
for col in ['order_id','order_item_id', 'sla', 'product_procurement_sla', 'product_mrp', 
 'units', 'gmv', 'listed_price', 'discount_percent', 'total_price', 'COD', 'luxury_product']:
  cam_df[col].fillna(cam_df[col].mean(), inplace=True)

cam_df.isna().sum()
# Out:
# week                       0
# special_sale               0
# Payday                     0
# Max Temp (°C)              0
# Min Temp (°C)              0
# Mean Temp (°C)             0
# Heat Deg Days (°C)         0
# Cool Deg Days (°C)         0
# Total Rain (mm)            0
# Total Snow (cm)            0
# Total Precip (mm)          0
# Snow on Grnd (cm)          0
# NPS                        0
# Stock_Index                0
# Total Investment           0
# TV                         0
# Digital                    0
# Sponsorship                0
# Content                    0
# Online                     0
# Affiliates                 0
# SEM                        0
# Radio                      0
# Other                      0
# TV_adstock                 0
# Digital_adstock            0
# Sponsorship_adstock        0
# Content_adstock            0
# Online_adstock             0
# Affiliates_adstock         0
# SEM_adstock                0
# Radio_adstock              0
# Other_adstock              0
# order_id                   0
# order_item_id              0
# sla                        0
# product_procurement_sla    0
# product_mrp                0
# units                      0
# gmv                        0
# listed_price               0
# discount_percent           0
# total_price                0
# COD                        0
# luxury_product             0
# dtype: int64

# %% [markdown]
# # EDA

# %%
cam_df.columns
# Out:
# Index(['week', 'special_sale', 'Payday', 'Max Temp (°C)', 'Min Temp (°C)',
#        'Mean Temp (°C)', 'Heat Deg Days (°C)', 'Cool Deg Days (°C)',
#        'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
#        'Snow on Grnd (cm)', 'NPS', 'Stock_Index', 'Total Investment', 'TV',
#        'Digital', 'Sponsorship', 'Content', 'Online', 'Affiliates', 'SEM',
#        'Radio', 'Other', 'TV_adstock', 'Digital_adstock',
#        'Sponsorship_adstock', 'Content_adstock', 'Online_adstock',
#        'Affiliates_adstock', 'SEM_adstock', 'Radio_adstock', 'Other_adstock',
#        'order_id', 'order_item_id', 'sla', 'product_procurement_sla',
#        'product_mrp', 'units', 'gmv', 'listed_price', 'discount_percent',
#        'total_price', 'COD', 'luxury_product'],
#       dtype='object')

# %%
# Sepearating the KPI's to their categories

pricing_kpi =  ['product_mrp', 'units', 'gmv', 'listed_price', 'discount_percent', 'total_price', 'special_sale', 'Payday', 'COD']
adv_kpi =      ['TV', 'Digital', 'Sponsorship', 'Content', 'Online', 'Affiliates', 'SEM', 'Radio', 'Other'] 
ad_stock_kpi = ['TV_adstock', 'Digital_adstock', 'Sponsorship_adstock',  'Content_adstock', 'Online_adstock',
                'Affiliates_adstock', 'SEM_adstock', 'Radio_adstock', 'Other_adstock']
other_kpi =        ['sla', 'product_procurement_sla', 'NPS', 'Stock_Index']
climate_Kpi =  ['Max Temp (°C)', 'Min Temp (°C)', 'Mean Temp (°C)', 'Heat Deg Days (°C)', 'Cool Deg Days (°C)',
               'Total Rain (mm)',  'Total Snow (cm)', 'Total Precip (mm)', 'Snow on Grnd (cm)']

# %%
# Reodering the important KPI's

cols = ['week', 'product_mrp', 'units', 'gmv', 'listed_price', 'discount_percent', 'total_price', 'special_sale', 'Payday', 'COD',
        'TV_adstock', 'Digital_adstock', 'Sponsorship_adstock',  'Content_adstock', 'Online_adstock','Affiliates_adstock', 
        'SEM_adstock', 'Radio_adstock', 'Other_adstock', 'sla', 'product_procurement_sla', 'NPS', 'Stock_Index', 
        'Max Temp (°C)', 'Min Temp (°C)', 'Mean Temp (°C)', 
        'Heat Deg Days (°C)', 'Cool Deg Days (°C)', 'Total Rain (mm)',  'Total Snow (cm)', 'Total Precip (mm)', 
        'Snow on Grnd (cm)']

# %%
cam_df = cam_df[cols]
cam_df.head()
# Out:
#    week  product_mrp  units     gmv  listed_price  discount_percent  \
# 0     1      965.292  1.000 421.375       421.375            46.355
# 1     2      914.269  1.000 444.974       444.974            45.287
# 2     3      967.026  1.000 449.302       449.302            45.778
# 3     4      952.331  1.000 445.664       445.664            44.456
# 4     5      977.362  1.000 457.440       457.440            44.936
#
#    total_price  special_sale  Payday      COD  TV_adstock  Digital_adstock  \
# 0      965.292         0.000   0.200    0.000       0.054            0.633
# 1      914.269         0.000   0.000 1459.000       0.081            0.950
# 2      967.026         0.286   0.143 1557.000       0.081            0.950
# 3      952.331         0.000   0.000 1591.000       0.081            0.950
# 4      977.362         0.000   0.143 1101.000       0.028            0.572
#
#    Sponsorship_adstock  Content_adstock  Online_adstock  Affiliates_adstock  \
# 0                1.854            0.000           0.332               0.137
# 1                2.780            0.000           0.498               0.205
# 2                2.780            0.000           0.498               0.205
# 3                2.780            0.000           0.498               0.205
# 4                1.139            0.000           0.192               0.083
#
#    SEM_adstock  Radio_adstock  Other_adstock   sla  product_procurement_sla  \
# 0        1.256          0.000          0.000 3.208                    2.542
# 1        1.884          0.000          0.000 7.366                    2.508
# 2        1.884          0.000          0.000 6.716                    2.524
# 3        1.884          0.000          0.000 6.770                    2.525
# 4        1.131          0.000          0.000 6.639                    2.546
#
#      NPS  Stock_Index  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0 54.600     1177.000         25.500         13.200          19.360
# 1 54.600     1177.000         24.025         14.385          19.263
# 2 54.600     1177.000         27.383         16.314          21.906
# 3 54.600     1177.000         28.240         14.342          20.540
# 4 56.139     1185.286         29.811         16.242          23.092
#
#    Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  Total Snow (cm)  \
# 0               0.100               1.460            0.000            0.000
# 1               1.059               2.322            4.155            0.029
# 2               0.816               4.722            1.569            0.029
# 3               1.632               4.172            1.141            0.029
# 4               0.816               5.908            4.341            0.029
#
#    Total Precip (mm)  Snow on Grnd (cm)
# 0              0.000              0.000
# 1              4.184              0.041
# 2              1.598              0.041
# 3              1.170              0.041
# 4              4.370              0.041

# %%
# Converting the bi-categorical features to binary feature

cam_df['Payday'] = cam_df['Payday'].apply(lambda x: 1 if x>0 else 0)
cam_df['special_sale'] = cam_df['special_sale'].apply(lambda x: 1 if x>0 else 0)

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Seeing the distribution of the different numeric features

# %%
# Price related features

features = ['sla', 'product_procurement_sla', 'product_mrp', 'units', 
            'gmv', 'listed_price', 'discount_percent', 'total_price']

plt.figure(figsize=(12,10))
for i, col in enumerate(features):
  plt.subplot(4, 2, i+1)
  sns.distplot(cam_df[col])

plt.tight_layout()

# %% [markdown]
# Most of the features are noramlly distribted

# %%
# Climate Related features

features =  ['Max Temp (°C)', 'Min Temp (°C)', 'Mean Temp (°C)',
       'Heat Deg Days (°C)', 'Cool Deg Days (°C)', 'Total Rain (mm)',
       'Total Snow (cm)', 'Total Precip (mm)', 'Snow on Grnd (cm)']

plt.figure(figsize=(12,10))
for i, col in enumerate(features):
  plt.subplot(3, 3, i+1)
  sns.distplot(cam_df[col])

plt.tight_layout()

# %% [markdown]
# *   All the climate realated features are normally distributed
# *   Though the year of time, the average rainfall is about 2.5mm
# *   The average temperature is about 13 degree C, which makes it a cool country
# *   Being the coldest country there is much snowfall in the Ontario

# %%
# Advertising or Marketing related

features =  [  'TV_adstock', 'Digital_adstock', 'Sponsorship_adstock',  'Content_adstock', 'Online_adstock',
                'Affiliates_adstock', 'SEM_adstock', 'Radio_adstock', 'Other_adstock']
plt.figure(figsize=(12,10))
for i, col in enumerate(features):
  plt.subplot(3, 3, i+1)
  sns.distplot(cam_df[col])

plt.tight_layout()

# %% [markdown]
# *   TV adstock has less impression for the Camera products about 2 days, which is unusual
#
# *   Sponsership and online has higher impression of about 7to8 days then any other

# %% [markdown]
# ## Bi-Variate Analysis

# %% [markdown]
# ### Behavior / trend of the various features over the weeks

# %%
# # order_id and order_item_id over the week

# features = ['order_id', 'order_item_id']

# plt.figure(figsize=(12,10))
# for i, col in enumerate(features):
#   plt.subplot(2, 1, i+1)
#   sns.barplot(cam_df['week'], cam_df[col])

# plt.tight_layout()

# %%
pricing_kpi
# Out:
# ['product_mrp',
#  'units',
#  'gmv',
#  'listed_price',
#  'discount_percent',
#  'total_price',
#  'special_sale',
#  'Payday',
#  'COD']

# %%
# GMV, Sale, discount, listed_price, total_price, SLA over the different weeks

features = ['gmv', 'product_mrp', 'listed_price', 'total_price', 'discount_percent', 'units',
            'special_sale', 'Payday', 'COD']

for col in features:
  plt.figure(figsize=(12, 7))
  sns.lineplot(cam_df['week'], cam_df[col])
  plt.show()

# %% [markdown]
# *   On the 18th week there is steep increase in the COD order and, between 41 and 43 their steep fall in COD orders
# *   On 6th week there is increase in the GMV or revenue

# %%
# NPS, stock_index over the weeks

features = ['NPS', 'Stock_Index']

plt.figure(figsize=(12,10))
for i, col in enumerate(features):
  plt.subplot(2, 1, i+1)
  sns.lineplot(cam_df['week'], cam_df[col])

plt.tight_layout()

# %% [markdown]
# Between 6th and 10th week the brand value or nps of the company is good

# %%
# COD over the weeks

features = ['COD']
plt.figure(figsize=(12,10))
for i, col in enumerate(features):
  plt.subplot(2, 1, i+1)
  sns.lineplot(cam_df['week'], cam_df[col])

plt.tight_layout()

# %%
# Correlation feturewise


kpis = [pricing_kpi, ad_stock_kpi, climate_Kpi, other_kpi]

for k in kpis:
  # plt.figure(figsize=())
  sns.heatmap(cam_df[k].corr(), cmap='inferno', annot=True)
  plt.show()

# %%
# Correlation of the important features

plt.figure(figsize=(15, 12))
sns.heatmap(cam_df.corr(), cmap='inferno')
plt.show()

# %%
cam_df.columns
# Out:
# Index(['week', 'product_mrp', 'units', 'gmv', 'listed_price',
#        'discount_percent', 'total_price', 'special_sale', 'Payday', 'COD',
#        'TV_adstock', 'Digital_adstock', 'Sponsorship_adstock',
#        'Content_adstock', 'Online_adstock', 'Affiliates_adstock',
#        'SEM_adstock', 'Radio_adstock', 'Other_adstock', 'sla',
#        'product_procurement_sla', 'NPS', 'Stock_Index', 'Max Temp (°C)',
#        'Min Temp (°C)', 'Mean Temp (°C)', 'Heat Deg Days (°C)',
#        'Cool Deg Days (°C)', 'Total Rain (mm)', 'Total Snow (cm)',
#        'Total Precip (mm)', 'Snow on Grnd (cm)'],
#       dtype='object')

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Mutiple Linear Regression

# %%
cam_df.head()
# Out:
#    week  product_mrp  units     gmv  listed_price  discount_percent  \
# 0     1      965.292  1.000 421.375       421.375            46.355
# 1     2      914.269  1.000 444.974       444.974            45.287
# 2     3      967.026  1.000 449.302       449.302            45.778
# 3     4      952.331  1.000 445.664       445.664            44.456
# 4     5      977.362  1.000 457.440       457.440            44.936
#
#    total_price  special_sale  Payday      COD  TV_adstock  Digital_adstock  \
# 0      965.292             0       1    0.000       0.054            0.633
# 1      914.269             0       0 1459.000       0.081            0.950
# 2      967.026             1       1 1557.000       0.081            0.950
# 3      952.331             0       0 1591.000       0.081            0.950
# 4      977.362             0       1 1101.000       0.028            0.572
#
#    Sponsorship_adstock  Content_adstock  Online_adstock  Affiliates_adstock  \
# 0                1.854            0.000           0.332               0.137
# 1                2.780            0.000           0.498               0.205
# 2                2.780            0.000           0.498               0.205
# 3                2.780            0.000           0.498               0.205
# 4                1.139            0.000           0.192               0.083
#
#    SEM_adstock  Radio_adstock  Other_adstock   sla  product_procurement_sla  \
# 0        1.256          0.000          0.000 3.208                    2.542
# 1        1.884          0.000          0.000 7.366                    2.508
# 2        1.884          0.000          0.000 6.716                    2.524
# 3        1.884          0.000          0.000 6.770                    2.525
# 4        1.131          0.000          0.000 6.639                    2.546
#
#      NPS  Stock_Index  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0 54.600     1177.000         25.500         13.200          19.360
# 1 54.600     1177.000         24.025         14.385          19.263
# 2 54.600     1177.000         27.383         16.314          21.906
# 3 54.600     1177.000         28.240         14.342          20.540
# 4 56.139     1185.286         29.811         16.242          23.092
#
#    Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  Total Snow (cm)  \
# 0               0.100               1.460            0.000            0.000
# 1               1.059               2.322            4.155            0.029
# 2               0.816               4.722            1.569            0.029
# 3               1.632               4.172            1.141            0.029
# 4               0.816               5.908            4.341            0.029
#
#    Total Precip (mm)  Snow on Grnd (cm)
# 0              0.000              0.000
# 1              4.184              0.041
# 2              1.598              0.041
# 3              1.170              0.041
# 4              4.370              0.041

# %% [markdown]
# ### Pre-Processing

# %% [markdown]
# Lets build the simple Linear Regression model with the most important features

# %%
cam_df.columns.values
# Out:
# array(['week', 'product_mrp', 'units', 'gmv', 'listed_price',
#        'discount_percent', 'total_price', 'special_sale', 'Payday', 'COD',
#        'TV_adstock', 'Digital_adstock', 'Sponsorship_adstock',
#        'Content_adstock', 'Online_adstock', 'Affiliates_adstock',
#        'SEM_adstock', 'Radio_adstock', 'Other_adstock', 'sla',
#        'product_procurement_sla', 'NPS', 'Stock_Index', 'Max Temp (°C)',
#        'Min Temp (°C)', 'Mean Temp (°C)', 'Heat Deg Days (°C)',
#        'Cool Deg Days (°C)', 'Total Rain (mm)', 'Total Snow (cm)',
#        'Total Precip (mm)', 'Snow on Grnd (cm)'], dtype=object)

# %%
# Dropping the unimportant or the columns which doesn't have much use to our model building

cam_df.drop(columns=['week', 'Stock_Index', 'Max Temp (°C)', 'Min Temp (°C)', 'Total Rain (mm)'], axis =1, inplace=True)

# %% [markdown]
# #### Dummy variable creation

# %%
# Dummy Variable creation
cam_df.select_dtypes('O').columns
# Out:
# Index([], dtype='object')

# %% [markdown]
# No need to create the dummy variables as there are no categorical variable

# %% [markdown]
# #### Train-Test Split

# %%
# Test-Train Split

from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(cam_df, train_size = 0.7, test_size = 0.3, random_state = 100)

# %% [markdown]
# #### Feature Scaling

# %%
df_train.head()
# Out:
#     product_mrp  units     gmv  listed_price  discount_percent  total_price  \
# 40     1087.892  1.000 385.121       385.121            55.824     1087.892
# 44     1082.217  1.000 336.842       336.842            60.626     1082.217
# 37     1097.426  1.000 380.201       380.201            56.374     1097.426
# 17      981.036  1.000 460.492       460.492            47.188      981.036
# 7      1016.351  1.000 416.457       416.457            50.362     1016.351
#
#     special_sale  Payday      COD  TV_adstock  Digital_adstock  \
# 40             0       0  179.000       1.952            0.327
# 44             0       0 4100.000       0.411            0.231
# 37             0       1 3006.000       3.488            0.788
# 17             0       1 2954.000       1.612            1.833
# 7              1       0 2395.725       0.002            0.383
#
#     Sponsorship_adstock  Content_adstock  Online_adstock  Affiliates_adstock  \
# 40                9.116            0.013           6.193               2.135
# 44                9.504            0.237           7.095               2.040
# 37               15.596            0.139           6.914               2.332
# 17               13.418            0.464           6.959               2.191
# 7                 0.319            0.000           0.039               0.022
#
#     SEM_adstock  Radio_adstock  Other_adstock   sla  product_procurement_sla  \
# 40        1.582          0.000          0.000 6.007                    2.239
# 44        2.073          0.330          1.496 5.832                    2.182
# 37        1.948          0.326          5.980 6.093                    2.249
# 17        5.035          0.000          0.000 6.639                    2.708
# 7         0.754          0.000          0.000 6.347                    2.419
#
#       NPS  Mean Temp (°C)  Heat Deg Days (°C)  Cool Deg Days (°C)  \
# 40 51.828           6.818              12.019               0.837
# 44 47.307          12.583               5.975               0.558
# 37 49.021          11.189               7.648               0.837
# 17 44.770          13.287               6.109               1.395
# 7  59.987          22.134               0.816               4.950
#
#     Total Snow (cm)  Total Precip (mm)  Snow on Grnd (cm)
# 40            0.402              2.852              0.124
# 44            0.058              2.340              0.082
# 37            0.029              0.684              0.041
# 17            0.146              2.249              0.206
# 7             0.029              4.798              0.041

# %%
df_train.columns
# Out:
# Index(['product_mrp', 'units', 'gmv', 'listed_price', 'discount_percent',
#        'total_price', 'special_sale', 'Payday', 'COD', 'TV_adstock',
#        'Digital_adstock', 'Sponsorship_adstock', 'Content_adstock',
#        'Online_adstock', 'Affiliates_adstock', 'SEM_adstock', 'Radio_adstock',
#        'Other_adstock', 'sla', 'product_procurement_sla', 'NPS',
#        'Mean Temp (°C)', 'Heat Deg Days (°C)', 'Cool Deg Days (°C)',
#        'Total Snow (cm)', 'Total Precip (mm)', 'Snow on Grnd (cm)'],
#       dtype='object')

# %%
# Min-Max Scaling

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df_train[df_train.columns] = scaler.fit_transform(df_train)
df_train.head()
# Out:
#     product_mrp  units   gmv  listed_price  discount_percent  total_price  \
# 40        0.660  0.000 0.351         0.351             0.756        0.660
# 44        0.652  0.000 0.032         0.032             1.000        0.652
# 37        0.674  0.000 0.319         0.319             0.784        0.674
# 17        0.507  0.000 0.849         0.849             0.317        0.507
# 7         0.557  0.000 0.558         0.558             0.478        0.557
#
#     special_sale  Payday   COD  TV_adstock  Digital_adstock  \
# 40         0.000   0.000 0.029       0.559            0.041
# 44         0.000   0.000 0.669       0.117            0.020
# 37         0.000   1.000 0.491       1.000            0.142
# 17         0.000   1.000 0.482       0.462            0.369
# 7          1.000   0.000 0.391       0.000            0.054
#
#     Sponsorship_adstock  Content_adstock  Online_adstock  Affiliates_adstock  \
# 40                0.280            0.010           0.676               0.815
# 44                0.292            0.184           0.775               0.778
# 37                0.486            0.107           0.755               0.891
# 17                0.417            0.359           0.760               0.836
# 7                 0.000            0.000           0.000               0.000
#
#     SEM_adstock  Radio_adstock  Other_adstock   sla  product_procurement_sla  \
# 40        0.074          0.000          0.000 0.227                    0.328
# 44        0.118          0.407          0.184 0.190                    0.249
# 37        0.106          0.403          0.736 0.245                    0.341
# 17        0.382          0.000          0.000 0.360                    0.970
# 7         0.000          0.000          0.000 0.299                    0.573
#
#      NPS  Mean Temp (°C)  Heat Deg Days (°C)  Cool Deg Days (°C)  \
# 40 0.477           0.017               0.952               0.142
# 44 0.187           0.365               0.439               0.094
# 37 0.297           0.281               0.581               0.142
# 17 0.024           0.408               0.450               0.236
# 7  1.000           0.942               0.000               0.838
#
#     Total Snow (cm)  Total Precip (mm)  Snow on Grnd (cm)
# 40            0.343              0.283              0.027
# 44            0.027              0.224              0.018
# 37            0.000              0.033              0.009
# 17            0.108              0.214              0.045
# 7             0.000              0.508              0.009

# %% [markdown]
# #### Splitting X-train and Y-train

# %%
# Splitting X-train and Y-train

y_train = df_train.pop('gmv')
x_train = df_train

# %% [markdown]
# ### Model Building

# %%
x_train.shape
# Out:
# (36, 26)

# %% [markdown]
# #### RFE - Recursive Feature Elimination

# %%
# Importing RFE and LinearRegression

from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
# Running RFE with the output number of the variable equal to 10
lm = LinearRegression()
lm.fit(x_train, y_train)

rfe = RFE(lm, 10)             # running RFE
rfe = rfe.fit(x_train, y_train)

# %%
list(zip(x_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('product_mrp', False, 2),
#  ('units', False, 17),
#  ('listed_price', True, 1),
#  ('discount_percent', True, 1),
#  ('total_price', False, 6),
#  ('special_sale', False, 3),
#  ('Payday', True, 1),
#  ('COD', False, 14),
#  ('TV_adstock', False, 7),
#  ('Digital_adstock', False, 9),
#  ('Sponsorship_adstock', True, 1),
#  ('Content_adstock', False, 8),
#  ('Online_adstock', True, 1),
#  ('Affiliates_adstock', False, 10),
#  ('SEM_adstock', False, 13),
#  ('Radio_adstock', True, 1),
#  ('Other_adstock', True, 1),
#  ('sla', False, 15),
#  ('product_procurement_sla', True, 1),
#  ('NPS', False, 12),
#  ('Mean Temp (°C)', True, 1),
#  ('Heat Deg Days (°C)', True, 1),
#  ('Cool Deg Days (°C)', False, 5),
#  ('Total Snow (cm)', False, 11),
#  ('Total Precip (mm)', False, 4),
#  ('Snow on Grnd (cm)', False, 16)]

# %%
# Extracting the RFE supported columns or top 20 features for our model building

col = x_train.columns[rfe.support_].values
col
# Out:
# array(['listed_price', 'discount_percent', 'Payday',
#        'Sponsorship_adstock', 'Online_adstock', 'Radio_adstock',
#        'Other_adstock', 'product_procurement_sla', 'Mean Temp (°C)',
#        'Heat Deg Days (°C)'], dtype=object)

# %%
# Unimportant columns which got eliminated through RFE

x_train.columns[~rfe.support_]
# Out:
# Index(['product_mrp', 'units', 'total_price', 'special_sale', 'COD',
#        'TV_adstock', 'Digital_adstock', 'Content_adstock',
#        'Affiliates_adstock', 'SEM_adstock', 'sla', 'NPS', 'Cool Deg Days (°C)',
#        'Total Snow (cm)', 'Total Precip (mm)', 'Snow on Grnd (cm)'],
#       dtype='object')

# %% [markdown]
# #### Statsmodel - for the detailed statistics

# %% [markdown]
# ##### Model 1

# %%
# Creating X_test dataframe with RFE selected variables

x_train_rfe = x_train[col]

# %%
# Adding a constant variable & importing the stats model

import statsmodels.api as sm  
x_train_rfe = sm.add_constant(x_train_rfe)

# %%
lm = sm.OLS(y_train,x_train_rfe).fit()   # Running the linear model

# %%
#Statistical summary of our linear model

print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.586e+29
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):               0.00
# Time:                        13:26:58   Log-Likelihood:                 1200.6
# No. Observations:                  36   AIC:                            -2379.
# Df Residuals:                      25   BIC:                            -2362.
# Df Model:                          10
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                    1.554e-15    3.2e-15      0.486      0.631   -5.03e-15    8.14e-15
# listed_price                1.0000   1.57e-15   6.36e+14      0.000       1.000       1.000
# discount_percent        -8.604e-16   1.51e-15     -0.568      0.575   -3.98e-15    2.26e-15
# Payday                  -2.776e-17   3.78e-16     -0.073      0.942   -8.06e-16     7.5e-16
# Sponsorship_adstock      -2.22e-16   1.25e-15     -0.178      0.860   -2.79e-15    2.35e-15
# Online_adstock           4.163e-16   1.54e-15      0.270      0.790   -2.76e-15     3.6e-15
# Radio_adstock            3.886e-16   2.07e-15      0.187      0.853   -3.88e-15    4.66e-15
# Other_adstock           -5.551e-16   1.77e-15     -0.314      0.756    -4.2e-15    3.09e-15
# product_procurement_sla  5.551e-16   9.96e-16      0.557      0.582    -1.5e-15    2.61e-15
# Mean Temp (°C)          -1.776e-15   3.46e-15     -0.513      0.613   -8.91e-15    5.36e-15
# Heat Deg Days (°C)      -2.442e-15   3.27e-15     -0.747      0.462   -9.18e-15     4.3e-15
# ==============================================================================
# Omnibus:                        3.914   Durbin-Watson:                   0.303
# Prob(Omnibus):                  0.141   Jarque-Bera (JB):                3.390
# Skew:                           0.748   Prob(JB):                        0.184
# Kurtosis:                       2.851   Cond. No.                         61.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
x = x_train_rfe
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                    Features     VIF
# 0                     const 403.650
# 9            Mean Temp (°C)  35.560
# 10       Heat Deg Days (°C)  34.130
# 6             Radio_adstock  17.740
# 7             Other_adstock  14.150
# 1              listed_price   8.850
# 5            Online_adstock   8.680
# 2          discount_percent   7.740
# 4       Sponsorship_adstock   5.690
# 8   product_procurement_sla   1.950
# 3                    Payday   1.370

# %% [markdown]
# ##### Model 2

# %%
# Dropping the column Mean Temp (°C)	

x_train_new = x_train_rfe.drop('Mean Temp (°C)', axis=1)

# %%
# Adding a constant variable
x_train_lm = sm.add_constant(x_train_new)
lm = sm.OLS(y_train,x_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.757e+28
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):               0.00
# Time:                        13:26:58   Log-Likelihood:                 1151.8
# No. Observations:                  36   AIC:                            -2284.
# Df Residuals:                      26   BIC:                            -2268.
# Df Model:                           9
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                    1.582e-15   4.85e-15      0.326      0.747   -8.39e-15    1.16e-14
# listed_price                1.0000   5.92e-15   1.69e+14      0.000       1.000       1.000
# discount_percent         5.551e-17   5.74e-15      0.010      0.992   -1.17e-14    1.19e-14
# Payday                   7.216e-16   1.37e-15      0.525      0.604    -2.1e-15    3.55e-15
# Sponsorship_adstock      2.359e-16    4.7e-15      0.050      0.960   -9.43e-15     9.9e-15
# Online_adstock           1.693e-15   5.68e-15      0.298      0.768   -9.98e-15    1.34e-14
# Radio_adstock            4.441e-16   7.76e-15      0.057      0.955   -1.55e-14    1.64e-14
# Other_adstock            2.776e-16   6.67e-15      0.042      0.967   -1.34e-14     1.4e-14
# product_procurement_sla  9.437e-16   3.78e-15      0.249      0.805   -6.83e-15    8.72e-15
# Heat Deg Days (°C)      -7.494e-16   3.94e-15     -0.190      0.851   -8.84e-15    7.35e-15
# ==============================================================================
# Omnibus:                        2.453   Durbin-Watson:                   0.104
# Prob(Omnibus):                  0.293   Jarque-Bera (JB):                1.399
# Skew:                           0.435   Prob(JB):                        0.497
# Kurtosis:                       3.421   Cond. No.                         31.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
x = x_train_new
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                   Features    VIF
# 0                    const 64.400
# 6            Radio_adstock 17.220
# 7            Other_adstock 13.950
# 1             listed_price  8.700
# 5           Online_adstock  8.130
# 2         discount_percent  7.700
# 4      Sponsorship_adstock  5.600
# 9       Heat Deg Days (°C)  3.420
# 8  product_procurement_sla  1.950
# 3                   Payday  1.250

# %% [markdown]
# ##### Model 3

# %%
# Dropping Radio which has high VIF

x_train_new = x_train_new.drop(['Radio_adstock'], axis=1)

# Adding a constant variable
x_train_lm = sm.add_constant(x_train_new)
lm = sm.OLS(y_train,x_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.448e+29
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):               0.00
# Time:                        13:26:58   Log-Likelihood:                 1188.3
# No. Observations:                  36   AIC:                            -2359.
# Df Residuals:                      27   BIC:                            -2344.
# Df Model:                           8
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                     1.11e-15   1.73e-15      0.643      0.526   -2.43e-15    4.65e-15
# listed_price                1.0000   2.11e-15   4.75e+14      0.000       1.000       1.000
# discount_percent         5.551e-17   2.04e-15      0.027      0.979   -4.14e-15    4.25e-15
# Payday                    1.11e-16   4.86e-16      0.228      0.821   -8.87e-16    1.11e-15
# Sponsorship_adstock      4.337e-16   1.36e-15      0.318      0.753   -2.36e-15    3.23e-15
# Online_adstock          -6.939e-17   1.72e-15     -0.040      0.968   -3.61e-15    3.47e-15
# Other_adstock            6.661e-16   8.58e-16      0.777      0.444   -1.09e-15    2.43e-15
# product_procurement_sla  3.886e-16   1.34e-15      0.289      0.774   -2.37e-15    3.14e-15
# Heat Deg Days (°C)      -4.163e-16   1.27e-15     -0.328      0.745   -3.02e-15    2.19e-15
# ==============================================================================
# Omnibus:                        2.925   Durbin-Watson:                   0.138
# Prob(Omnibus):                  0.232   Jarque-Bera (JB):                1.610
# Skew:                          -0.214   Prob(JB):                        0.447
# Kurtosis:                       2.056   Cond. No.                         26.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model

vif = pd.DataFrame()
x = x_train_new
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                   Features    VIF
# 0                    const 64.380
# 1             listed_price  8.680
# 2         discount_percent  7.700
# 5           Online_adstock  5.910
# 4      Sponsorship_adstock  3.710
# 8       Heat Deg Days (°C)  2.800
# 7  product_procurement_sla  1.930
# 6            Other_adstock  1.820
# 3                   Payday  1.240

# %% [markdown]
# ##### Model 4

# %%
# Dropping listed_price which has high VIF

x_train_new = x_train_new.drop(['listed_price'], axis=1)

# Adding a constant variable
x_train_lm = sm.add_constant(x_train_new)
lm = sm.OLS(y_train,x_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.885
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     30.71
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):           1.62e-11
# Time:                        13:26:58   Log-Likelihood:                 31.006
# No. Observations:                  36   AIC:                            -46.01
# Df Residuals:                      28   BIC:                            -33.34
# Df Model:                           7
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.6775      0.087      7.747      0.000       0.498       0.857
# discount_percent           -0.8582      0.086    -10.013      0.000      -1.034      -0.683
# Payday                      0.0277      0.043      0.639      0.528      -0.061       0.116
# Sponsorship_adstock         0.0526      0.122      0.431      0.670      -0.197       0.302
# Online_adstock              0.2881      0.145      1.989      0.057      -0.009       0.585
# Other_adstock              -0.1055      0.074     -1.419      0.167      -0.258       0.047
# product_procurement_sla     0.2579      0.110      2.339      0.027       0.032       0.484
# Heat Deg Days (°C)         -0.0746      0.113     -0.660      0.514      -0.306       0.157
# ==============================================================================
# Omnibus:                        2.748   Durbin-Watson:                   1.879
# Prob(Omnibus):                  0.253   Jarque-Bera (JB):                1.733
# Skew:                          -0.138   Prob(JB):                        0.420
# Kurtosis:                       4.039   Cond. No.                         16.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model

vif = pd.DataFrame()
x = x_train_new
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                   Features    VIF
# 0                    const 20.480
# 4           Online_adstock  5.180
# 3      Sponsorship_adstock  3.690
# 7       Heat Deg Days (°C)  2.760
# 5            Other_adstock  1.700
# 1         discount_percent  1.680
# 6  product_procurement_sla  1.620
# 2                   Payday  1.220

# %% [markdown]
# ##### Model 5

# %%
# Dropping Online_adstock which has high P-Value

x_train_new = x_train_new.drop(['Online_adstock'], axis=1)

# Adding a constant variable
x_train_lm = sm.add_constant(x_train_new)
lm = sm.OLS(y_train,x_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.868
# Model:                            OLS   Adj. R-squared:                  0.841
# Method:                 Least Squares   F-statistic:                     31.92
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):           1.65e-11
# Time:                        13:26:58   Log-Likelihood:                 28.626
# No. Observations:                  36   AIC:                            -43.25
# Df Residuals:                      29   BIC:                            -32.17
# Df Model:                           6
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.6692      0.092      7.297      0.000       0.482       0.857
# discount_percent           -0.7936      0.083     -9.530      0.000      -0.964      -0.623
# Payday                      0.0062      0.044      0.140      0.889      -0.084       0.096
# Sponsorship_adstock         0.2520      0.073      3.458      0.002       0.103       0.401
# Other_adstock              -0.0629      0.075     -0.842      0.407      -0.216       0.090
# product_procurement_sla     0.3005      0.114      2.648      0.013       0.068       0.533
# Heat Deg Days (°C)          0.0844      0.084      1.006      0.323      -0.087       0.256
# ==============================================================================
# Omnibus:                        5.606   Durbin-Watson:                   1.770
# Prob(Omnibus):                  0.061   Jarque-Bera (JB):                4.184
# Skew:                          -0.640   Prob(JB):                        0.123
# Kurtosis:                       4.072   Cond. No.                         11.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model

vif = pd.DataFrame()
x = x_train_new
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                   Features    VIF
# 0                    const 20.430
# 5  product_procurement_sla  1.560
# 4            Other_adstock  1.550
# 1         discount_percent  1.440
# 6       Heat Deg Days (°C)  1.380
# 3      Sponsorship_adstock  1.190
# 2                   Payday  1.150

# %% [markdown]
# ##### Model 6

# %%
# Dropping Digital which has high VIF / P-Value

x_train_new = x_train_new.drop(['Payday'], axis=1)

# Adding a constant variable
x_train_lm = sm.add_constant(x_train_new)
lm = sm.OLS(y_train,x_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.868
# Model:                            OLS   Adj. R-squared:                  0.846
# Method:                 Least Squares   F-statistic:                     39.59
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):           2.49e-12
# Time:                        13:26:58   Log-Likelihood:                 28.614
# No. Observations:                  36   AIC:                            -45.23
# Df Residuals:                      30   BIC:                            -35.73
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.6677      0.090      7.454      0.000       0.485       0.851
# discount_percent           -0.7917      0.081     -9.797      0.000      -0.957      -0.627
# Sponsorship_adstock         0.2520      0.072      3.516      0.001       0.106       0.398
# Other_adstock              -0.0651      0.072     -0.907      0.372      -0.212       0.082
# product_procurement_sla     0.3050      0.107      2.848      0.008       0.086       0.524
# Heat Deg Days (°C)          0.0871      0.080      1.085      0.287      -0.077       0.251
# ==============================================================================
# Omnibus:                        5.303   Durbin-Watson:                   1.759
# Prob(Omnibus):                  0.071   Jarque-Bera (JB):                3.910
# Skew:                          -0.601   Prob(JB):                        0.142
# Kurtosis:                       4.079   Cond. No.                         10.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model

vif = pd.DataFrame()
x = x_train_new
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                   Features    VIF
# 0                    const 20.160
# 3            Other_adstock  1.480
# 4  product_procurement_sla  1.430
# 1         discount_percent  1.400
# 5       Heat Deg Days (°C)  1.310
# 2      Sponsorship_adstock  1.190

# %% [markdown]
# ##### Model 7

# %%
# Dropping Other_adstock which has high VIF / P-Value

x_train_new = x_train_new.drop(['Other_adstock'], axis=1)

# Adding a constant variable
x_train_lm = sm.add_constant(x_train_new)
lm = sm.OLS(y_train,x_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     49.57
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):           4.89e-13
# Time:                        13:26:58   Log-Likelihood:                 28.127
# No. Observations:                  36   AIC:                            -46.25
# Df Residuals:                      31   BIC:                            -38.34
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.6809      0.088      7.725      0.000       0.501       0.861
# discount_percent           -0.8058      0.079    -10.188      0.000      -0.967      -0.644
# Sponsorship_adstock         0.2751      0.067      4.117      0.000       0.139       0.411
# product_procurement_sla     0.2812      0.104      2.716      0.011       0.070       0.492
# Heat Deg Days (°C)          0.0543      0.071      0.760      0.453      -0.091       0.200
# ==============================================================================
# Omnibus:                        4.117   Durbin-Watson:                   1.708
# Prob(Omnibus):                  0.128   Jarque-Bera (JB):                2.721
# Skew:                          -0.566   Prob(JB):                        0.256
# Kurtosis:                       3.731   Cond. No.                         9.59
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model

vif = pd.DataFrame()
x = x_train_new
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                   Features    VIF
# 0                    const 19.630
# 1         discount_percent  1.350
# 3  product_procurement_sla  1.350
# 2      Sponsorship_adstock  1.040
# 4       Heat Deg Days (°C)  1.040

# %% [markdown]
# ##### Modle 8

# %%
# Dropping Online which has high VIF / P-Value

x_train_new = x_train_new.drop(['Heat Deg Days (°C)'], axis=1)

# Adding a constant variable
x_train_lm = sm.add_constant(x_train_new)
lm = sm.OLS(y_train,x_train_lm).fit()   # Running the linear model

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    gmv   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                     66.78
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):           7.22e-14
# Time:                        13:26:58   Log-Likelihood:                 27.795
# No. Observations:                  36   AIC:                            -47.59
# Df Residuals:                      32   BIC:                            -41.26
# Df Model:                           3
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       0.7013      0.083      8.408      0.000       0.531       0.871
# discount_percent           -0.7972      0.078    -10.252      0.000      -0.956      -0.639
# Sponsorship_adstock         0.2708      0.066      4.095      0.000       0.136       0.406
# product_procurement_sla     0.2784      0.103      2.709      0.011       0.069       0.488
# ==============================================================================
# Omnibus:                        3.654   Durbin-Watson:                   1.711
# Prob(Omnibus):                  0.161   Jarque-Bera (JB):                2.384
# Skew:                          -0.575   Prob(JB):                        0.304
# Kurtosis:                       3.516   Cond. No.                         9.10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the new model

vif = pd.DataFrame()
x = x_train_new
vif['Features'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                   Features    VIF
# 0                    const 17.810
# 3  product_procurement_sla  1.340
# 1         discount_percent  1.320
# 2      Sponsorship_adstock  1.040

# %% [markdown]
# #### Residual Analysis of the train data
#
# So, now to check if the error terms are also normally distributed (which is infact, one of the major assumptions of linear regression), let us plot the histogram of the error terms and see what it looks like.

# %%
y_train_pred = lm.predict(x_train_lm)

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_pred), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)                         # X-label
# Out:
# Text(0.5, 0, 'Errors')

# %%
# RMSE
from sklearn.metrics import mean_squared_error

rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
rmse
# Out:
# 0.11180250142210672

# %% [markdown]
# #### Making Predictions

# %% [markdown]
# ##### Applying the scaling on the test sets

# %%
col = df_test.columns

# %%
df_test[col] = scaler.transform(df_test[col])

# %% [markdown]
# ##### Dividing into X_test and y_test

# %%
y_test = df_test.pop('gmv')
x_test = df_test

# %%
x_train_new.columns
# Out:
# Index(['const', 'discount_percent', 'Sponsorship_adstock',
#        'product_procurement_sla'],
#       dtype='object')

# %%
# Now let's use our model to make predictions.

# Creating X_test_new dataframe by dropping variables from X_test
x_test_new = x_test[['discount_percent', 'Sponsorship_adstock', 'product_procurement_sla']]

# Adding a constant variable 
x_test_new = sm.add_constant(x_test_new)

# %%
# Making predictions
y_pred = lm.predict(x_test_new)

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading 
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)                          # Y-label
# Out:
# Text(0, 0.5, 'y_pred')
